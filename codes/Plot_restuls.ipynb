# %%
#plot
import json
import unicodecsv as csv
import pickle
import numpy as np
import cv2
from tqdm import tqdm

# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # attribute

# %%
file_place="../experiment1a/mean_accuracy.txt"
train = np.loadtxt(open(file_place,"rb"),delimiter=",",skiprows=0)
file_place="../experiment1a/val_mean_accuracy.txt"
val = np.loadtxt(open(file_place,"rb"),delimiter=",",skiprows=0)

plt.plot(train,label = "train",color="blue")
plt.plot(val,label = "val",color="red")
plt.show()

np.max(val)
# Out:
# 0.16042279779999999

# %%
file_place="../experiment2a/mean_accuracy.txt"
train = np.loadtxt(open(file_place,"rb"),delimiter=",",skiprows=0)
file_place="../experiment2a/val_mean_accuracy.txt"
val = np.loadtxt(open(file_place,"rb"),delimiter=",",skiprows=0)

plt.plot(train,label = "train",color="blue")
plt.plot(val,label = "val",color="red")
plt.show()

np.max(val)
# Out:
# 0.31031516194300002

# %% [markdown]
# # relations

# %%
file_place="../experiment1/mean_accuracy.txt"
train = np.loadtxt(open(file_place,"rb"),delimiter=",",skiprows=0)
file_place="../experiment1/val_mean_accuracy.txt"
val = np.loadtxt(open(file_place,"rb"),delimiter=",",skiprows=0)

plt.plot(train,label = "train",color="blue")
plt.plot(val,label = "val",color="red")
plt.show()

np.max(val)
# Out:
# 0.32024068614399998

# %%
file_place="../experiment2/mean_accuracy.txt"
train = np.loadtxt(open(file_place,"rb"),delimiter=",",skiprows=0)
file_place="../experiment2/val_mean_accuracy.txt"
val = np.loadtxt(open(file_place,"rb"),delimiter=",",skiprows=0)

plt.plot(train,label = "train",color="blue")
plt.plot(val,label = "val",color="red")
plt.show()

np.max(val)
# Out:
# 0.31343554763199999

# %%
file_place="../experiment3/mean_accuracy.txt"
train = np.loadtxt(open(file_place,"rb"),delimiter=",",skiprows=0)
file_place="../experiment3/val_mean_accuracy.txt"
val = np.loadtxt(open(file_place,"rb"),delimiter=",",skiprows=0)

plt.plot(train,label = "train",color="blue")
plt.plot(val,label = "val",color="red")
plt.show()

np.max(val)
# Out:
# 0.31039740153399997

# %%
file_place="../experiment4/mean_accuracy.txt"
train = np.loadtxt(open(file_place,"rb"),delimiter=",",skiprows=0)
file_place="../experiment4/val_mean_accuracy.txt"
val = np.loadtxt(open(file_place,"rb"),delimiter=",",skiprows=0)

plt.plot(train,label = "train",color="blue")
plt.plot(val,label = "val",color="red")
plt.show()

np.max(val)
# Out:
# 0.321622743426

# %%
file_place="../experiment5/mean_accuracy.txt"
train = np.loadtxt(open(file_place,"rb"),delimiter=",",skiprows=0)
file_place="../experiment5/val_mean_accuracy.txt"
val = np.loadtxt(open(file_place,"rb"),delimiter=",",skiprows=0)

plt.plot(train,label = "train",color="blue")
plt.plot(val,label = "val",color="red")
plt.show()

np.max(val)
# Out:
# 0.32049158060100003

# %%
file_place="../experiment6/mean_accuracy.txt"
train = np.loadtxt(open(file_place,"rb"),delimiter=",",skiprows=0)
file_place="../experiment6/val_mean_accuracy.txt"
val = np.loadtxt(open(file_place,"rb"),delimiter=",",skiprows=0)

plt.plot(train,label = "train",color="blue")
plt.plot(val,label = "val",color="red")
plt.show()

np.max(val)
# Out:
# 0.31581225330500001
